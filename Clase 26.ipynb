# %% [markdown]
# # Clase 26

# %%
import numpy as np
import pandas as pd

# %%
import sqlite3

# %%
sql = "SELECT name FROM sqlite_master WHERE type = 'table'"

# %%
con = sqlite3.connect ("C:/Users/mi13966/Downloads/nba_salary.sqlite")

# %%
list_tables = pd.read_sql_query(sql, con)

# %%
print(list_tables)
# Out:
#                     name
# 0  NBA_season1718_salary
# 1          Seasons_Stats

# %%
con.close()

# %%
sql = "SELECT * FROM NBA_season1718_salary WHERE 1=1"
con = sqlite3.connect ("C:/Users/mi13966/Downloads/nba_salary.sqlite")
df = pd.read_sql_query(sql, con)

# %%
df.head()
# Out:
#     X1          Player   Tm  season17_18
# 0  1.0   Stephen Curry  GSW   34682550.0
# 1  2.0    LeBron James  CLE   33285709.0
# 2  3.0    Paul Millsap  DEN   31269231.0
# 3  4.0  Gordon Hayward  BOS   29727900.0
# 4  5.0   Blake Griffin  DET   29512900.0

# %% [markdown]
# ## Desafio Generico: ACCEDEMOS A BASE DE DATOS DESDE PANDAS

# %% [markdown]
# 1) Leer el dataset de utilizado para extraer solo los jugadores con mayor salario que 10 millones de dólares.

# %%
sql = "SELECT * FROM NBA_season1718_salary WHERE season17_18 > 10000000 "
con = sqlite3.connect ("C:/Users/mi13966/Downloads/nba_salary.sqlite")
df = pd.read_sql_query(sql, con)
df.head()
# Out:
#     X1          Player   Tm  season17_18
# 0  1.0   Stephen Curry  GSW   34682550.0
# 1  2.0    LeBron James  CLE   33285709.0
# 2  3.0    Paul Millsap  DEN   31269231.0
# 3  4.0  Gordon Hayward  BOS   29727900.0
# 4  5.0   Blake Griffin  DET   29512900.0

# %% [markdown]
# 2) Extraer de esos jugadores las estadísticas correspondientes a ese año que provienen de la tabla Season_Stats del año 2017.

# %%
sql = "SELECT * FROM Seasons_Stats WHERE YEAR=2017 "
df = pd.read_sql_query(sql, con)
df.head()
# Out:
#         X1    Year        Player Pos   Age   Tm     G   GS      MP   PER  ...  \
# 0  24096.0  2017.0  Alex Abrines  SG  23.0  OKC  68.0  NaN  1055.0  10.1  ...
# 1  24097.0  2017.0    Quincy Acy  PF  26.0  TOT  38.0  1.0   558.0  11.8  ...
# 2  24098.0  2017.0    Quincy Acy  PF  26.0  DAL   6.0  0.0    48.0  -1.4  ...
# 3  24099.0  2017.0    Quincy Acy  PF  26.0  BRK  32.0  1.0   510.0  13.1  ...
# 4  24100.0  2017.0  Steven Adams   C  23.0  OKC  80.0  NaN  2389.0  16.5  ...
#
#      FT%  ORB  DRB    TRB   AST  STL  BLK  TOV     PF    PTS
# 0  0.898  NaN  NaN   86.0  40.0  NaN  NaN  NaN  114.0  406.0
# 1  0.750  NaN  NaN  115.0  18.0  NaN  NaN  NaN   67.0  222.0
# 2  0.667  NaN  NaN    8.0   0.0  0.0  0.0  NaN    9.0   13.0
# 3  0.754  NaN  NaN  107.0  18.0  NaN  NaN  NaN   58.0  209.0
# 4  0.611  NaN  NaN  615.0  86.0  NaN  NaN  NaN  195.0  905.0
#
# [5 rows x 53 columns]

# %% [markdown]
# 3) Calcular de la tabla Season_Stats el promedio total de puntos PTS, asistencias AST y faltas personales PF.

# %%
sql = "SELECT AVG(PTS), AVG(AST), AVG(PF)  FROM Seasons_Stats WHERE  1=1"
df = pd.read_sql_query(sql, con)
df.head()
# Out:
#     AVG(PTS)    AVG(AST)     AVG(PF)
# 0  510.11635  114.852623  116.339222

# %% [markdown]
# ## Ejemplo

# %%
import json
import requests
url = 'https://raw.githubusercontent.com/bttmly/nba/master/data/teams.json'
respuesta= requests.get(url)
print(respuesta)
# Out:
# <Response [200]>

# %%
jsondata = json.loads(respuesta.text)

# %%
df = pd.DataFrame.from_dict(jsondata)

# %%
df
# Out:
#         teamId abbreviation                teamName     simpleName  \
# 0   1610612737          ATL           Atlanta Hawks          Hawks
# 1   1610612738          BOS          Boston Celtics        Celtics
# 2   1610612751          BKN           Brooklyn Nets           Nets
# 3   1610612766          CHA       Charlotte Hornets        Hornets
# 4   1610612741          CHI           Chicago Bulls          Bulls
# 5   1610612739          CLE     Cleveland Cavaliers      Cavaliers
# 6   1610612742          DAL        Dallas Mavericks      Mavericks
# 7   1610612743          DEN          Denver Nuggets        Nuggets
# 8   1610612765          DET         Detroit Pistons        Pistons
# 9   1610612744          GSW   Golden State Warriors       Warriors
# 10  1610612745          HOU         Houston Rockets        Rockets
# 11  1610612754          IND          Indiana Pacers         Pacers
# 12  1610612746          LAC    Los Angeles Clippers       Clippers
# ...
