# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np

# Preprocesado y modelado
# ==============================================================================
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

# %%
#Cargamos los datos!
url = 'https://raw.githubusercontent.com/JoaquinAmatRodrigo/' \
       + 'Estadistica-machine-learning-python/master/data/ESL.mixture.csv'
datos = pd.read_csv(url)
datos.head()
# Out:
#          X1        X2  y
# 0  2.526093  0.321050  0
# 1  0.366954  0.031462  0
# 2  0.768219  0.717486  0
# 3  0.693436  0.777194  0
# 4 -0.019837  0.867254  0

# %%
#Visualizacion!
fig, ax = plt.subplots(figsize=(6,4))
ax.scatter(datos.X1, datos.X2, c=datos.y);
ax.set_title("Datos");

# %%
# División de los datos en train y test
X = datos.drop(columns = 'y')
y = datos['y']

X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y.values.reshape(-1,1),
                                        train_size   = 0.7,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %%
# Creación del modelo SVM 
#Paso 1
modelo = SVC(C = 100, kernel = 'poly', random_state=123)
#Paso 2
modelo.fit(X_train, y_train)
# Out:
# SVC(C=100, kernel='poly', random_state=123)

# %%
#Predicciones!
#Paso 3
y_train_pred = modelo.predict(X_train)
y_test_pred = modelo.predict(X_test)

# %%
#Calculo el accuracy en Train
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de evaluación:',train_accuracy)
# Out:
# % de aciertos sobre el set de evaluación: 0.7357142857142858

# %%
#Calculo el accuracy en Test con Lineal
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación: 0.7166666666666667

# %%
#Calculo el accuracy en Test con RBF
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación: 0.8333333333333334

# %%
#Calculo el accuracy en Test con poly
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación: 0.8333333333333334
